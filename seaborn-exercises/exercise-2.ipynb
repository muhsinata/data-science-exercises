# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Get Data
cars = sns.load_dataset("mpg")

# Drop Na Values
cars.dropna(inplace=True)

# See Data
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Draw Seaborn KDE Plot

sns.set_theme()
plt.tight_layout()

sns.kdeplot(cars.horsepower, fill=True, bw_adjust=.2)

plt.show()

# %%
sns.set_theme(style="whitegrid")

# Load Data From Seaborn
diamonds = sns.load_dataset("diamonds")

# Get Variables
carat = diamonds.carat
price = diamonds.price
clarity = diamonds.clarity
depth = diamonds.depth
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

# %%
# Draw Scatter Plot

f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.scatterplot(x=carat, y=price, hue=clarity, hue_order=clarity_ranking,
                size=depth, palette="ch:r=-.2,d=.3_r", sizes=(1, 8), linewidth=0,
                ax=ax)
plt.show()
