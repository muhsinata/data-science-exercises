# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Load Data

penguins = sns.load_dataset("penguins")
penguins.dropna(inplace=True)
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
# Draw Histogram

plt.tight_layout()
sns.set_theme(style="darkgrid")
sns.histplot(x="bill_length_mm", data=penguins, kde=True)
plt.show()

# %%
# Add Cumulative Histogram

sns.histplot(x="bill_length_mm", data=penguins, element="step",
             stat="probability", cumulative=True)

plt.show()

# %%
# Include Categorical Data Information Into Histogram

sns.histplot(x="bill_length_mm", data=penguins, element="poly",
             hue="species")

plt.show()

# %%
# Add Stacked Histogram

sns.histplot(x="bill_length_mm", multiple="stack",
             hue="species", data=penguins)

plt.show()

# %%
# Fill Space Under The Histogram

sns.histplot(x="bill_length_mm", multiple="fill",
             hue="species", data=penguins, stat="percent")

plt.show()

# %%
# Create Bivariate Histogram Graph

g = sns.histplot(x="bill_length_mm", y="bill_depth_mm", data=penguins, hue="species",
             cbar=True)
sns.move_legend(g, loc="upper right", bbox_to_anchor=(2.5, 1))
plt.show()

# %%
# Create A Histogram That Shows Species-Specific Sex Distribution 

sns.histplot(x="species", hue="sex", multiple="dodge", shrink=0.8, data=penguins)
plt.show()
